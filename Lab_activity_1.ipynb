# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhi-max/lab-activity-1/blob/main/Lab_activity_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# hardcoded

# %%
import matplotlib.pyplot as plt
import numpy as np

def Quadratic_model(time):
  a = 0.1
  b = -1
  c = 50
  temperature = a * (time**2) + b * time + c
  return temperature

def main():
    time_values=np.linspace(0,10,50)
    temperature_hardcode=Quadratic_model(time_values)
    plt.plot(time_values , temperature_hardcode)
    plt.xlabel('time')
    plt.ylabel('temperature')
    plt.legend()
    plt.title('weather modeling with quadratic equation')
    plt.show()

# Fix the indentation of this line
if __name__ == "__main__":
     main()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# user input

# %%
import numpy as np
import matplotlib.pyplot as plt

def Quadratic_model(time, a, b, c):
    temperature = a * (time**2) + b * time + c
    return temperature

def main():
    a = float(input("Enter the value of a: "))
    b = float(input("Enter the value of b: "))
    c = float(input("Enter the value of c: "))

    time_values = np.linspace(0, 10, 50)
    temperature_hardcode = Quadratic_model(time_values, a, b, c)

    plt.plot(time_values, temperature_hardcode)
    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.title('Weather Modeling with Quadratic Equation')
    plt.grid(True)
    plt.show()


if __name__ == "__main__":
    main()
# Out:
# Enter the value of a: 15
# Enter the value of b: 20
# Enter the value of c: 12

# %% [markdown]
# hard coded and user input

# %%
import matplotlib.pyplot as plt
import numpy as np
def quadratic_model(time):
  #User Input coefficients for the equation
  a = float(input('Enter the value for a:'))
  b = float(input('Enter the value for b:'))
  c = float(input('Enter the value for c:'))
  #quadratic eq representing temp change
  temperature = a*(time**2)+b*time+c
  return temperature
def quadratic_mol(time):
  a = 10
  b = -0.6
  c = 45
  temperature = a*(time**2)+b*time+c
  return temperature
def main() :
  #time values from 0 to 10
  time_values = np.linspace(0,10,50)
  #calculate temperature using User Input variables
  temperature_hardcoded1 = quadratic_model(time_values)
  #plot the results
  plt.plot(time_values,temperature_hardcoded1,label = 'User Input Coefficients (3,4,5)')
  temperature_hardcoded2 = quadratic_mol(time_values)
  plt.plot(time_values,temperature_hardcoded2,label = 'Hard-coded Coefficients (0,10,50 )')
  plt.xlabel('Time')
  plt.ylabel('Temperature')
  plt.legend()
  plt.title('Weather modelling with quadratic Equation(User Input and Hard-coded)')
  plt.show()
if __name__ == "__main__":
  main()
# Out:
# Enter the value for a:3
# Enter the value for b:4
# Enter the value for c:5

# %% [markdown]
# multiple inputs

# %%
import matplotlib.pyplot as plt
import numpy as np
def quadratic_model(m,time):
  #hard-coded coefficients for the quation
  a = m[0]
  b = m[0]
  c = m[0]
  #quadratic eq representing temp change
  temperature = a*(time**2)+b*time+c
  return temperature
def main() :
  lst = [(34,5,45),(-6,0,21),(23,-50,-7),(23,-50,8)]
  #time values from 0 to 10
  time_values = np.linspace(0,10,50)
  #calculate temperature using hardcoded variables
  temperature_hardcoded = quadratic_model(lst[0],time_values)
  plt.plot(time_values,temperature_hardcoded,label = 'Set1 (34,5,45)')
  temperature_hardcoded = quadratic_model(lst[1],time_values)
  plt.plot(time_values,temperature_hardcoded,label = 'Set2 (-6,0,21)')
  temperature_hardcoded = quadratic_model(lst[2],time_values)
  plt.plot(time_values,temperature_hardcoded,label = 'Set3 (23,-50,-7)')

  plt.xlabel('Time')
  plt.ylabel('Temperature')
  plt.legend()
  plt.grid()
  plt.title('Weather modelling with quadratic Equation(Multiple Coefficients) ')
  plt.show()
if __name__ == "__main__":
  main()
